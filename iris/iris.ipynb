# %%
import numpy as np
import seaborn as ssn
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
np.shape(df)
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
df.variety.value_counts()
# Out:
# Versicolor    50
# Setosa        50
# Virginica     50
# Name: variety, dtype: int64

# %%
df.plot(kind='scatter',x='sepal.length',y='sepal.width')
plt.show()

# %%
# We can't differentiate between the different kind of petal
# Hence we will be use very famous lib. called seaBorn
ssn.set_style("whitegrid");
ssn.FacetGrid(df,hue='variety',height=4)\
    .map(plt.scatter,'sepal.length','sepal.width')\
    .add_legend();
plt.show();

# %%
# We can't draw 3d plane or more than that on simple paper.
# But we have to consider every perspective of data.
# We can use the pairPlot idea to solve it.
# We will draw graph between every possible pair.
# The number of graph with n different attributes will be C(n,2).
# To draw this we will use the ssn(seaBorn) lib.
plt.close()

ssn.set_style("whitegrid")
ssn.pairplot(df,hue="variety",height=3)
plt.show()

# Pair plot are fairly easy to understand but as soon as dataset reaches to 10 it will be
# very difficult to understand it

# %%
# univariant analysis using pdf(Probability Distribution function)

ssn.set_style('whitegrid')
ssn.FacetGrid(df,hue='variety',height=5)\
    .map(ssn.distplot,'petal.length')\
    .add_legend()
plt.show()

# %%
ssn.set_style('whitegrid')
ssn.FacetGrid(df,hue='variety',size=5)\
    .map(ssn.distplot,'petal.width')\
    .add_legend()
plt.show()
# Out:
# /home/ashutosh/PycharmProjects/iris/venv/lib/python3.7/site-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
ssn.set_style('whitegrid')
ssn.FacetGrid(df,hue='variety',size=5)\
    .map(ssn.distplot,'sepal.length')\
    .add_legend()
plt.show()
# Out:
# /home/ashutosh/PycharmProjects/iris/venv/lib/python3.7/site-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
ssn.set_style('whitegrid')
ssn.FacetGrid(df,hue='variety',size=5)\
    .map(ssn.distplot,'sepal.width')\
    .add_legend()
plt.show()
# Out:
# /home/ashutosh/PycharmProjects/iris/venv/lib/python3.7/site-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# How to draw a pdf(Probability distribution function.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
iris = pd.read_csv('iris.csv')
count,bins_edges = np.histogram(iris['petal.length'],bins=10,density=True)
pdf = count/(sum(count))
print(pdf)
print(bins_edges)
# Out:
# [0.24666667 0.08666667 0.         0.02       0.05333333 0.17333333
#  0.19333333 0.12       0.07333333 0.03333333]
# [1.   1.59 2.18 2.77 3.36 3.95 4.54 5.13 5.72 6.31 6.9 ]

# %%
cdf = np.cumsum(pdf)
plt.plot(bins_edges[1:],pdf,color='r',label='pdf')
plt.plot(bins_edges[1:],cdf,color='g',label='cdf')
plt.xlabel('petal_length')
plt.ylabel('probability')
plt.legend()
plt.grid()
plt.show()

# %%
count,bins_edges = np.histogram(iris['petal.width'],bins=10,density=True)
pdf = count/(sum(count))
print(pdf)
print(bins_edges)
# Out:
# [0.27333333 0.05333333 0.00666667 0.04666667 0.05333333 0.22
#  0.04       0.15333333 0.06       0.09333333]
# [0.1  0.34 0.58 0.82 1.06 1.3  1.54 1.78 2.02 2.26 2.5 ]

# %%
cdf = np.cumsum(pdf)
plt.plot(bins_edges[1:],pdf,color='r',label='pdf')
plt.plot(bins_edges[1:],cdf,color='g',label='cdf')
plt.xlabel('petal_width')
plt.ylabel('probability')
plt.legend()
plt.grid()
plt.show()

# %%
# Calculate mean, median , standard deviation of each type of species.
g = iris.groupby('variety')
for group_name,items in g:
    print(group_name)
    print(items)
# Out:
# Setosa
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
g.describe()
# Out:
#            sepal.length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# variety
# Setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal.width         ... petal.length      petal.width         \
#                  count   mean  ...          75%  max       count   mean
# variety                        ...
# Setosa            50.0  3.428  ...        1.575  1.9        50.0  0.246
# Versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# Virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# variety
# Setosa      0.105386  0.1  0.2  0.2  0.3  0.6
# Versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# Virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# ...

# %%
# Calculate percentile of the data.
# A more specific term called quantiles of the data.
# 1st quantiles is 25%
# 2nd quntiles is called median(50%)
# 3rd and 4th quantiles are respectivly 75% and 100% .
for group_names,items in g:
    print()
    print("-------------------")
    print(group_names)
    print("0%\t25%\t50%\t75%")
    for col in items.columns[:4]:
        print(col)
        print(np.percentile(items[col],np.arange(0,100,25)))
# Out:
# -------------------
# Setosa
# 0%	25%	50%	75%
# sepal.length
# [4.3 4.8 5.  5.2]
# sepal.width
# [2.3   3.2   3.4   3.675]
# petal.length
# [1.    1.4   1.5   1.575]
# petal.width
# [0.1 0.2 0.2 0.3]
#
# -------------------
# Versicolor
# 0%	25%	50%	75%
# sepal.length
# [4.9 5.6 5.9 6.3]
# sepal.width
# [2.    2.525 2.8   3.   ]
# petal.length
# [3.   4.   4.35 4.6 ]
# petal.width
# [1.  1.2 1.3 1.5]
#
# -------------------
# Virginica
# 0%	25%	50%	75%
# sepal.length
# [4.9   6.225 6.5   6.9  ]
# sepal.width
# [2.2   2.8   3.    3.175]
# petal.length
# [4.5   5.1   5.55  5.875]
# petal.width
# [1.4 1.8 2.  2.3]

# %%
# Calculating 90th percentile
for group_name, items in g:
    print()
    print("-------------------")
    print(group_name)
    for col in items.columns[:4]:
        print(col)
        print(np.percentile(items[col],90))
# Out:
# -------------------
# Setosa
# sepal.length
# 5.41
# sepal.width
# 3.9
# petal.length
# 1.7
# petal.width
# 0.4
#
# -------------------
# Versicolor
# sepal.length
# 6.7
# sepal.width
# 3.1100000000000003
# petal.length
# 4.8
# petal.width
# 1.5100000000000002
#
# -------------------
# Virginica
# sepal.length
# 7.61
# sepal.width
# 3.31
# petal.length
# 6.3100000000000005
# petal.width
# 2.4

# %%
# Calculate mad
from statsmodels import robust
for group_name , items in g:
    print()
    print('-----------------------------')
    print(group_name)
    for col in items.columns[:4]:
        print(col)
        print(robust.mad(items[col]))
# Out:
# -----------------------------
# Setosa
# sepal.length
# 0.29652044370112063
# sepal.width
# 0.3706505546264005
# petal.length
# 0.14826022185056031
# petal.width
# 0.0
#
# -----------------------------
# Versicolor
# sepal.length
# 0.5189107764769608
# sepal.width
# 0.29652044370112063
# petal.length
# 0.5189107764769602
# petal.width
# 0.2223903327758403
#
# -----------------------------
# Virginica
# sepal.length
# 0.5930408874022413
# sepal.width
# 0.29652044370112063
# petal.length
# 0.6671709983275211
# petal.width
# 0.2965204437011203

# %%
# BoxPlot
col = iris.columns
print(col)
for i in col[:4]:
    sns.boxplot(x=col[4],y=i,data=iris)
    plt.show()
    plt.close()
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
# violinPlot -> pdf+histogram + boxplot
for i in col[:4]:
    sns.violinplot(x=col[4],y=i,data=iris)
    plt.show()
    plt.close()

# %%
for i in col[:4]:
    sns.barplot(x=col[4],y=i,data=iris)
    plt.show()
    plt.close()

# %%
for group_name , items in g:
    print(group_name)
    sns.jointplot(x='petal.length',y='petal.width',data=items,kind="kde")
    plt.show()
    plt.close()
# Out:
# Setosa
# Versicolor
# Virginica
